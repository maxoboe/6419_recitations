# %%
import pandas as pd
import numpy as np
from nhanes.load import load_NHANES_data, load_NHANES_metadata
data_df = load_NHANES_data(year='2017-2018')
metadata_df = load_NHANES_metadata(year='2017-2018')

# %%
pd.unique(data_df.GeneralHealthCondition)
# Out:
# array([nan, 'Good', 'Very good', 'Fair or', 'Excellent', 'Poor?'],
#       dtype=object)

# %%
data_df[data_df.GeneralHealthCondition == 'Poor?']
# Out:
#          GeneralHealthCondition  EverBreastfedOrFedBreastmilk  \
# SEQN
# 93740.0                   Poor?                           NaN
# 93760.0                   Poor?                           NaN
# 93834.0                   Poor?                           NaN
# 93847.0                   Poor?                           NaN
# 93894.0                   Poor?                           NaN
# ...                         ...                           ...
# 102775.0                  Poor?                           NaN
# 102778.0                  Poor?                           NaN
# 102815.0                  Poor?                           NaN
# 102854.0                  Poor?                           NaN
# 102911.0                  Poor?                           NaN
#
#           AgeStoppedBreastfeedingdays  AgeFirstFedFormuladays  \
# SEQN
# 93740.0                           NaN                     NaN
# 93760.0                           NaN                     NaN
# 93834.0                           NaN                     NaN
# 93847.0                           NaN                     NaN
# 93894.0                           NaN                     NaN
# ...                               ...                     ...
# 102775.0                          NaN                     NaN
# 102778.0                          NaN                     NaN
# 102815.0                          NaN                     NaN
# 102854.0                          NaN                     NaN
# 102911.0                          NaN                     NaN
#
#           AgeStoppedReceivingFormuladays  AgeStartedOtherFoodbeverage  \
# SEQN
# 93740.0                              NaN                          NaN
# 93760.0                              NaN                          NaN
# 93834.0                              NaN                          NaN
# 93847.0                              NaN                          NaN
# 93894.0                              NaN                          NaN
# ...                                  ...                          ...
# 102775.0                             NaN                          NaN
# 102778.0                             NaN                          NaN
# 102815.0                             NaN                          NaN
# 102854.0                             NaN                          NaN
# 102911.0                             NaN                          NaN
#
#           AgeFirstFedMilkdays TypeOfMilkFirstFedWholeMilk  \
# SEQN
# 93740.0                   NaN                         NaN
# 93760.0                   NaN                         NaN
# 93834.0                   NaN                         NaN
# 93847.0                   NaN                         NaN
# 93894.0                   NaN                         NaN
# ...                       ...                         ...
# 102775.0                  NaN                         NaN
# 102778.0                  NaN                         NaN
# 102815.0                  NaN                         NaN
# 102854.0                  NaN                         NaN
# 102911.0                  NaN                         NaN
#
#           TypeOfMilkFirstFed2Milk  TypeOfMilkFirstFed1Milk  ...  \
# SEQN                                                        ...
# 93740.0                       NaN                      NaN  ...
# 93760.0                       NaN                      NaN  ...
# 93834.0                       NaN                      NaN  ...
# 93847.0                       NaN                      NaN  ...
# 93894.0                       NaN                      NaN  ...
# ...                           ...                      ...  ...
# 102775.0                      NaN                      NaN  ...
# 102778.0                      NaN                      NaN  ...
# 102815.0                      NaN                      NaN  ...
# 102854.0                      NaN                      NaN  ...
# 102911.0                      NaN                      NaN  ...
#
#           DaysSmokedCigsDuringPast30Days  AvgCigarettesdayDuringPast30Days  \
# SEQN
# 93740.0                             30.0                               5.0
# 93760.0                              NaN                               NaN
# 93834.0                              NaN                               NaN
# 93847.0                              NaN                               NaN
# 93894.0                             30.0                              20.0
# ...                                  ...                               ...
# 102775.0                             NaN                               NaN
# 102778.0                             NaN                               NaN
# 102815.0                             NaN                               NaN
# 102854.0                             NaN                               NaN
# 102911.0                            30.0                              20.0
#
#           TriedToQuitSmoking TimesStoppedSmokingCigarettes  \
# SEQN
# 93740.0                  1.0                           5.0
# 93760.0                  NaN                           NaN
# 93834.0                  NaN                           NaN
# 93847.0                  NaN                           NaN
# 93894.0                  0.0                           NaN
# ...                      ...                           ...
# 102775.0                 NaN                           NaN
# 102778.0                 NaN                           NaN
# 102815.0                 NaN                           NaN
# 102854.0                 NaN                           NaN
# 102911.0                 0.0                           NaN
#
#          HowLongWereYouAbleToStopSmoking UnitOfMeasureDayweekmonthyear_2_SMQ  \
# SEQN
# 93740.0                              2.0                                Days
# 93760.0                              NaN                                 NaN
# 93834.0                              NaN                                 NaN
# 93847.0                              NaN                                 NaN
# 93894.0                              NaN                                 NaN
# ...                                  ...                                 ...
# 102775.0                             NaN                                 NaN
# 102778.0                             NaN                                 NaN
# 102815.0                             NaN                                 NaN
# 102854.0                             NaN                                 NaN
# 102911.0                             NaN                                 NaN
#
#           CurrentSelfreportedHeightInches  CurrentSelfreportedWeightPounds  \
# SEQN
# 93740.0                              73.0                            235.0
# 93760.0                            9999.0                            198.0
# 93834.0                              65.0                            230.0
# 93847.0                              64.0                            215.0
# 93894.0                              63.0                            165.0
# ...                                   ...                              ...
# 102775.0                             72.0                            284.0
# 102778.0                             66.0                            484.0
# 102815.0                             67.0                            130.0
# 102854.0                             65.0                            240.0
# 102911.0                             66.0                            135.0
#
#           TriedToLoseWeightInPastYear  TimesLost10LbsOrMoreToLoseWeight
# SEQN
# 93740.0                           0.0                             Never
# 93760.0                           0.0                             Never
# 93834.0                           0.0                             Never
# 93847.0                           1.0                             Never
# 93894.0                           0.0                            1 to 2
# ...                               ...                               ...
# 102775.0                          1.0                            1 to 2
# 102778.0                          NaN                            3 to 5
# 102815.0                          0.0                             Never
# 102854.0                          1.0                  11 times or more
# 102911.0                          0.0                             Never
#
# [172 rows x 197 columns]

# %%
metadata_df[metadata_df.Type == 'Numeric']
# Out:
#                                     Variable     Type  Format  Informat  \
# VariableNameLong
# GeneralHealthCondition                HSD010  Numeric     NaN       NaN
# EverBreastfedOrFedBreastmilk          DBQ010  Numeric     NaN       NaN
# AgeStoppedBreastfeedingdays           DBD030  Numeric     NaN       NaN
# AgeFirstFedFormuladays                DBD041  Numeric     NaN       NaN
# AgeStoppedReceivingFormuladays        DBD050  Numeric     NaN       NaN
# ...                                      ...      ...     ...       ...
# UnitOfMeasureDayweekmonthyear_2_SMQ  SMQ852U  Numeric     NaN       NaN
# CurrentSelfreportedHeightInches       WHD010  Numeric     NaN       NaN
# CurrentSelfreportedWeightPounds       WHD020  Numeric     NaN       NaN
# TriedToLoseWeightInPastYear           WHQ070  Numeric     NaN       NaN
# TimesLost10LbsOrMoreToLoseWeight      WHQ225  Numeric     NaN       NaN
#
#                                                                         Label  \
# VariableNameLong
# GeneralHealthCondition                               General health condition
# EverBreastfedOrFedBreastmilk                 Ever breastfed or fed breastmilk
# AgeStoppedBreastfeedingdays                   Age stopped breastfeeding(days)
# AgeFirstFedFormuladays                            Age first fed formula(days)
# AgeStoppedReceivingFormuladays            Age stopped receiving formula(days)
# ...                                                                       ...
# UnitOfMeasureDayweekmonthyear_2_SMQ     Unit of measure (day/week/month/year)
# CurrentSelfreportedHeightInches         Current self-reported height (inches)
# CurrentSelfreportedWeightPounds         Current self-reported weight (pounds)
# TriedToLoseWeightInPastYear                 Tried to lose weight in past year
# TimesLost10LbsOrMoreToLoseWeight     Times lost 10 lbs or more to lose weight
#
#                                     Source VariableName  \
# VariableNameLong
# GeneralHealthCondition                 HSQ       HSD010
# EverBreastfedOrFedBreastmilk           DBQ       DBQ010
# AgeStoppedBreastfeedingdays            DBQ       DBD030
# AgeFirstFedFormuladays                 DBQ       DBD041
# AgeStoppedReceivingFormuladays         DBQ       DBD050
# ...                                    ...          ...
# UnitOfMeasureDayweekmonthyear_2_SMQ    SMQ      SMQ852U
# CurrentSelfreportedHeightInches        WHQ       WHD010
# CurrentSelfreportedWeightPounds        WHQ       WHD020
# TriedToLoseWeightInPastYear            WHQ       WHQ070
# TimesLost10LbsOrMoreToLoseWeight       WHQ       WHQ225
#
#                                                                      SASLabel  \
# VariableNameLong
# GeneralHealthCondition                               General health condition
# EverBreastfedOrFedBreastmilk                 Ever breastfed or fed breastmilk
# AgeStoppedBreastfeedingdays                   Age stopped breastfeeding(days)
# AgeFirstFedFormuladays                            Age first fed formula(days)
# AgeStoppedReceivingFormuladays            Age stopped receiving formula(days)
# ...                                                                       ...
# UnitOfMeasureDayweekmonthyear_2_SMQ     Unit of measure (day/week/month/year)
# CurrentSelfreportedHeightInches         Current self-reported height (inches)
# CurrentSelfreportedWeightPounds         Current self-reported weight (pounds)
# TriedToLoseWeightInPastYear                 Tried to lose weight in past year
# TimesLost10LbsOrMoreToLoseWeight     Times lost 10 lbs or more to lose weight
#
#                                                                            EnglishText  \
# VariableNameLong
# GeneralHealthCondition               Next I have some general questions about {your...
# EverBreastfedOrFedBreastmilk         Now I'm going to ask you some general question...
# AgeStoppedBreastfeedingdays          How old was {SP} when {he/she} completely stop...
# AgeFirstFedFormuladays               How old was {SP} when {he/she} was first fed f...
# AgeStoppedReceivingFormuladays       How old was {SP} when {he/she} completely stop...
# ...                                                                                ...
# UnitOfMeasureDayweekmonthyear_2_SMQ  The last time {you/SP} tried to quit, how long...
# CurrentSelfreportedHeightInches      These next questions ask about {your/SP's} hei...
# CurrentSelfreportedWeightPounds      How much {do you/does SP} weigh without clothe...
# TriedToLoseWeightInPastYear          During the past 12 months, {have you/has SP} t...
# TimesLost10LbsOrMoreToLoseWeight     How many times {have you/has SP} lost 10 pound...
#
#                                                                                 Target  \
# VariableNameLong
# GeneralHealthCondition                Both males and females 12 YEARS -\n\n\t\t\t15...
# EverBreastfedOrFedBreastmilk          Both males and females 0 YEARS -\n\n\t\t\t6 Y...
# AgeStoppedBreastfeedingdays           Both males and females 0 YEARS -\n\n\t\t\t6 Y...
# AgeFirstFedFormuladays                Both males and females 0 YEARS -\n\n\t\t\t6 Y...
# AgeStoppedReceivingFormuladays        Both males and females 0 YEARS -\n\n\t\t\t6 Y...
# ...                                                                                ...
# UnitOfMeasureDayweekmonthyear_2_SMQ   Both males and females 18 YEARS -\n\n\t\t\t15...
# CurrentSelfreportedHeightInches       Both males and females 16 YEARS -\n\n\t\t\t15...
# CurrentSelfreportedWeightPounds       Both males and females 16 YEARS -\n\n\t\t\t15...
# TriedToLoseWeightInPastYear           Both males and females 16 YEARS -\n\n\t\t\t15...
# TimesLost10LbsOrMoreToLoseWeight      Both males and females 16 YEARS -\n\n\t\t\t15...
#
#                                          VariableNameLong_variable_df  \
# VariableNameLong
# GeneralHealthCondition                         GeneralHealthCondition
# EverBreastfedOrFedBreastmilk             EverBreastfedOrFedBreastmilk
# AgeStoppedBreastfeedingdays               AgeStoppedBreastfeedingdays
# AgeFirstFedFormuladays                         AgeFirstFedFormuladays
# AgeStoppedReceivingFormuladays         AgeStoppedReceivingFormuladays
# ...                                                               ...
# UnitOfMeasureDayweekmonthyear_2_SMQ     UnitOfMeasureDayweekmonthyear
# CurrentSelfreportedHeightInches       CurrentSelfreportedHeightInches
# CurrentSelfreportedWeightPounds       CurrentSelfreportedWeightPounds
# TriedToLoseWeightInPastYear               TriedToLoseWeightInPastYear
# TimesLost10LbsOrMoreToLoseWeight     TimesLost10LbsOrMoreToLoseWeight
#
#                                     Source_variable_df  \
# VariableNameLong
# GeneralHealthCondition                             HSQ
# EverBreastfedOrFedBreastmilk                       DBQ
# AgeStoppedBreastfeedingdays                        DBQ
# AgeFirstFedFormuladays                             DBQ
# AgeStoppedReceivingFormuladays                     DBQ
# ...                                                ...
# UnitOfMeasureDayweekmonthyear_2_SMQ                SMQ
# CurrentSelfreportedHeightInches                    WHQ
# CurrentSelfreportedWeightPounds                    WHQ
# TriedToLoseWeightInPastYear                        WHQ
# TimesLost10LbsOrMoreToLoseWeight                   WHQ
#
#                                                                    EnglishInstructions  \
# VariableNameLong
# GeneralHealthCondition                                                             NaN
# EverBreastfedOrFedBreastmilk                                                       NaN
# AgeStoppedBreastfeedingdays                                                        NaN
# AgeFirstFedFormuladays                                                             NaN
# AgeStoppedReceivingFormuladays                                                     NaN
# ...                                                                                ...
# UnitOfMeasureDayweekmonthyear_2_SMQ                                         ENTER UNIT
# CurrentSelfreportedHeightInches      ENTER HEIGHT IN FEET AND INCHES OR METERS AND ...
# CurrentSelfreportedWeightPounds      RECORD CURRENT WEIGHT. IF PREGNANT, ASK FOR WE...
# TriedToLoseWeightInPastYear                                                        NaN
# TimesLost10LbsOrMoreToLoseWeight                                                   NaN
#
#                                     HardEdits  Recoded CustomRecoding  nNonNA
# VariableNameLong
# GeneralHealthCondition                    NaN     True            NaN  5964.0
# EverBreastfedOrFedBreastmilk              NaN     True          YesNo  1069.0
# AgeStoppedBreastfeedingdays               NaN    False            NaN   862.0
# AgeFirstFedFormuladays                    NaN    False            NaN  1077.0
# AgeStoppedReceivingFormuladays            NaN    False            NaN   891.0
# ...                                       ...      ...            ...     ...
# UnitOfMeasureDayweekmonthyear_2_SMQ       NaN     True            NaN   496.0
# CurrentSelfreportedHeightInches           NaN    False            NaN  5776.0
# CurrentSelfreportedWeightPounds           NaN    False            NaN  5828.0
# TriedToLoseWeightInPastYear               NaN     True          YesNo  5087.0
# TimesLost10LbsOrMoreToLoseWeight          NaN     True            NaN  5794.0
#
# [195 rows x 17 columns]
